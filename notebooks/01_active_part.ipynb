# %% [markdown]
# # 01 — The active part
#
# `CurrentPart()` returns whatever part document is on top in Alibre, as a
# typed `IADPartSession`.
#
# **Prereq:** open any part in Alibre (File → New → Part).

# %%
from alibrex import CurrentPart

# %%
part = CurrentPart()
part.Name

# %% [markdown]
# How many features does the part have?

# %%
part.FeatureCount

# %% [markdown]
# How many bodies?

# %%
part.Bodies.Count
