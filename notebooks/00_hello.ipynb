# %% [markdown]
# # 00 - Hello, alibrex
#
# The bare minimum: confirm we can reach a running Alibre instance.
#
# **Prereq:** Alibre Design must be running.

# %%
from alibrex import connect_to_running_alibre

# %%
connect_to_running_alibre().Version
